# %% [markdown]
# <a href="https://colab.research.google.com/github/BANOTHSANDEEP5/stockmarket/blob/main/MTPDecisionTreeRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sb

# %%
dataset = pd.read_excel('data.xlsx')

# %%
dataset
# Out:
#                Reference    Mix ID  water/binder   Binder (kg/m^3)  \
# 0    Younsi et al. (2011)     RefI           0.60              301
# 1    Younsi et al. (2011)    RefII           0.54              321
# 2    Younsi et al. (2011)     FA30           0.53              301
# 3    Younsi et al. (2011)    FA50*           0.41              239
# 4    Younsi et al. (2011)     FA50           0.41              239
# ..                    ...      ...            ...              ...
# 237   Cheng et al. (2008)  WB50-40           0.50              414
# 238   Cheng et al. (2008)     WB70           0.70              296
# 239   Cheng et al. (2008)  WB70-10           0.70              296
# 240   Cheng et al. (2008)  WB70-20           0.70              296
# 241   Cheng et al. (2008)  WB70-40           0.70              296
#
#      Fly ash (%)  GGBS (%)  SP (%)  Aggregate (CA/ FA)  Curing Days  \
# 0              0         0    0.00                1.27           28
# 1              0         0    1.00                1.27           28
# 2            100         0    1.75                1.27           28
# 3            190         0    6.00                1.27           28
# 4            190         0    6.00                1.27           28
# ..           ...       ...     ...                 ...          ...
# 237            0        40    0.10                1.35           56
# 238            0         0    0.00                1.20           56
# 239            0        10    0.00                1.20           56
# 240            0        20    0.00                1.20           56
# 241            0        40    0.00                1.20           56
#
#     Curing condition  Porosity (%)
# 0                Air          16.0
# 1                Air          16.0
# 2                Air          15.9
# 3                Air          16.8
# 4                Air          16.3
# ..               ...           ...
# 237              Air           6.2
# 238              Air           7.4
# 239              Air           8.2
# 240              Air           7.2
# 241              Air           6.8
#
# [242 rows x 11 columns]

# %%
dataset = dataset.iloc[:, 2:]

# %%
dataset
# Out:
#      water/binder   Binder (kg/m^3)  Fly ash (%)  GGBS (%)  SP (%)  \
# 0             0.60              301            0         0    0.00
# 1             0.54              321            0         0    1.00
# 2             0.53              301          100         0    1.75
# 3             0.41              239          190         0    6.00
# 4             0.41              239          190         0    6.00
# ..             ...              ...          ...       ...     ...
# 237           0.50              414            0        40    0.10
# 238           0.70              296            0         0    0.00
# 239           0.70              296            0        10    0.00
# 240           0.70              296            0        20    0.00
# 241           0.70              296            0        40    0.00
#
#      Aggregate (CA/ FA)  Curing Days Curing condition  Porosity (%)
# 0                  1.27           28              Air          16.0
# 1                  1.27           28              Air          16.0
# 2                  1.27           28              Air          15.9
# 3                  1.27           28              Air          16.8
# 4                  1.27           28              Air          16.3
# ..                  ...          ...              ...           ...
# 237                1.35           56              Air           6.2
# 238                1.20           56              Air           7.4
# 239                1.20           56              Air           8.2
# 240                1.20           56              Air           7.2
# 241                1.20           56              Air           6.8
#
# [242 rows x 9 columns]

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
dataset['Curing condition'] = le.fit_transform(dataset['Curing condition'])

# %%
dataset
# Out:
#      water/binder   Binder (kg/m^3)  Fly ash (%)  GGBS (%)  SP (%)  \
# 0             0.60              301            0         0    0.00
# 1             0.54              321            0         0    1.00
# 2             0.53              301          100         0    1.75
# 3             0.41              239          190         0    6.00
# 4             0.41              239          190         0    6.00
# ..             ...              ...          ...       ...     ...
# 237           0.50              414            0        40    0.10
# 238           0.70              296            0         0    0.00
# 239           0.70              296            0        10    0.00
# 240           0.70              296            0        20    0.00
# 241           0.70              296            0        40    0.00
#
#      Aggregate (CA/ FA)  Curing Days  Curing condition  Porosity (%)
# 0                  1.27           28                 0          16.0
# 1                  1.27           28                 0          16.0
# 2                  1.27           28                 0          15.9
# 3                  1.27           28                 0          16.8
# 4                  1.27           28                 0          16.3
# ..                  ...          ...               ...           ...
# 237                1.35           56                 0           6.2
# 238                1.20           56                 0           7.4
# 239                1.20           56                 0           8.2
# 240                1.20           56                 0           7.2
# 241                1.20           56                 0           6.8
#
# [242 rows x 9 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242 entries, 0 to 241
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   water/binder        242 non-null    float64
#  1   Binder (kg/m^3)     242 non-null    int64
#  2   Fly ash (%)         242 non-null    int64
#  3   GGBS (%)            242 non-null    int64
#  4   SP (%)              242 non-null    float64
#  5   Aggregate (CA/ FA)  242 non-null    float64
#  6   Curing Days         242 non-null    int64
#  7   Curing condition    242 non-null    int64
#  8   Porosity (%)        242 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 17.1 KB

# %%
dataset.isnull().sum()
# Out:
# water/binder          0
# Binder (kg/m^3)       0
# Fly ash (%)           0
# GGBS (%)              0
# SP (%)                0
# Aggregate (CA/ FA)    0
# Curing Days           0
# Curing condition      0
# Porosity (%)          0
# dtype: int64

# %%
dataset.describe()
# Out:
#        water/binder   Binder (kg/m^3)  Fly ash (%)    GGBS (%)      SP (%)  \
# count     242.000000       242.000000   242.000000  242.000000  242.000000
# mean        0.479339       367.446281    18.198347    4.338843    0.317769
# std         0.098185        75.706131    29.213940   10.573633    0.932023
# min         0.350000       239.000000     0.000000    0.000000    0.000000
# 25%         0.400000       325.000000     0.000000    0.000000    0.000000
# 50%         0.500000       350.000000    10.000000    0.000000    0.000000
# 75%         0.540000       400.000000    30.000000    0.000000    0.100000
# max         0.700000       591.000000   190.000000   40.000000    6.000000
#
#        Aggregate (CA/ FA)  Curing Days  Curing condition  Porosity (%)
# count          242.000000   242.000000        242.000000    242.000000
# mean             1.701074    88.851240          0.169421     10.398140
# std              0.289669   108.798772          0.375901      2.800595
# min              1.200000     1.000000          0.000000      2.200000
# 25%              1.500000    28.000000          0.000000      8.400000
# 50%              1.700000    28.000000          0.000000     10.355000
# 75%              2.000000    91.000000          0.000000     12.175000
# max              2.000000   365.000000          1.000000     18.200000

# %%
dataset['Porosity (%)'].value_counts()
# Out:
# 8.2     9
# 10.8    7
# 8.4     6
# 7.4     5
# 9.6     5
#        ..
# 8.3     1
# 7.5     1
# 7.9     1
# 9.1     1
# 6.2     1
# Name: Porosity (%), Length: 122, dtype: int64

# %%
dataset.corr()
# Out:
#                     water/binder   Binder (kg/m^3)  Fly ash (%)  GGBS (%)  \
# water/binder             1.000000        -0.510701    -0.182718  0.156652
# Binder (kg/m^3)         -0.510701         1.000000    -0.303545  0.360420
# Fly ash (%)             -0.182718        -0.303545     1.000000 -0.256679
# GGBS (%)                 0.156652         0.360420    -0.256679  1.000000
# SP (%)                  -0.255108         0.049214     0.708347 -0.022592
# Aggregate (CA/ FA)      -0.536601         0.102857    -0.001790 -0.404564
# Curing Days             -0.178849        -0.151126     0.062790 -0.264544
# Curing condition         0.175059        -0.286408     0.216836 -0.185713
# Porosity (%)             0.207586        -0.453192     0.387024 -0.307085
#
#                       SP (%)  Aggregate (CA/ FA)  Curing Days  \
# water/binder       -0.255108           -0.536601    -0.178849
# Binder (kg/m^3)     0.049214            0.102857    -0.151126
# Fly ash (%)         0.708347           -0.001790     0.062790
# GGBS (%)           -0.022592           -0.404564    -0.264544
# SP (%)              1.000000           -0.221466    -0.156901
# Aggregate (CA/ FA) -0.221466            1.000000     0.532675
# Curing Days        -0.156901            0.532675     1.000000
# Curing condition    0.020389           -0.357981    -0.159380
# Porosity (%)        0.315094            0.027882    -0.156452
#
#                     Curing condition  Porosity (%)
# water/binder                0.175059      0.207586
# Binder (kg/m^3)            -0.286408     -0.453192
# Fly ash (%)                 0.216836      0.387024
# GGBS (%)                   -0.185713     -0.307085
# SP (%)                      0.020389      0.315094
# Aggregate (CA/ FA)         -0.357981      0.027882
# Curing Days                -0.159380     -0.156452
# Curing condition            1.000000     -0.010460
# Porosity (%)               -0.010460      1.000000

# %%
plt.figure(figsize=[30, 30])

# Loop through columns
for i, col in enumerate(dataset.columns):
    plt.subplot(4, 3, i + 1)  # Use 'i' to index the subplots
    sb.barplot(data=dataset, x=col, y='Porosity (%)')  # Swap x and y for barplot
    plt.title(f'Porosity for {col}')  # Add a title for each subplot

plt.tight_layout()  # Adjust the layout for better spacing
plt.show()

# %%
corrMatrix = dataset.corr()
plt.gcf().set_size_inches(10,9)
sb.heatmap(corrMatrix, annot=True)
plt.show()

# %%
target = dataset['Porosity (%)']
features = dataset.drop('Porosity (%)',axis=1)

# %%
target
# Out:
# 0      16.0
# 1      16.0
# 2      15.9
# 3      16.8
# 4      16.3
#        ...
# 237     6.2
# 238     7.4
# 239     8.2
# 240     7.2
# 241     6.8
# Name: Porosity (%), Length: 242, dtype: float64

# %%
features
# Out:
#      water/binder   Binder (kg/m^3)  Fly ash (%)  GGBS (%)  SP (%)  \
# 0             0.60              301            0         0    0.00
# 1             0.54              321            0         0    1.00
# 2             0.53              301          100         0    1.75
# 3             0.41              239          190         0    6.00
# 4             0.41              239          190         0    6.00
# ..             ...              ...          ...       ...     ...
# 237           0.50              414            0        40    0.10
# 238           0.70              296            0         0    0.00
# 239           0.70              296            0        10    0.00
# 240           0.70              296            0        20    0.00
# 241           0.70              296            0        40    0.00
#
#      Aggregate (CA/ FA)  Curing Days  Curing condition
# 0                  1.27           28                 0
# 1                  1.27           28                 0
# 2                  1.27           28                 0
# 3                  1.27           28                 0
# 4                  1.27           28                 0
# ..                  ...          ...               ...
# 237                1.35           56                 0
# 238                1.20           56                 0
# 239                1.20           56                 0
# 240                1.20           56                 0
# 241                1.20           56                 0
#
# [242 rows x 8 columns]

# %%
from sklearn.model_selection import train_test_split, cross_val_score
X_train, X_test, y_train, y_test = train_test_split(features,target, test_size = 0.25)

# %%
y_train
# Out:
# 157     9.90
# 69     11.00
# 105    11.30
# 16     15.80
# 173    13.09
#        ...
# 102    10.50
# 171    10.49
# 37     12.20
# 203    12.30
# 109    12.60
# Name: Porosity (%), Length: 181, dtype: float64

# %%
X_train
# Out:
#      water/binder   Binder (kg/m^3)  Fly ash (%)  GGBS (%)  SP (%)  \
# 157          0.500              350           30         0     0.0
# 69           0.385              350            0         0     0.0
# 105          0.500              350           10         0     0.0
# 16           0.400              400           50         0     2.5
# 173          0.400              300            0         0     0.0
# ..             ...              ...          ...       ...     ...
# 102          0.450              350           30         0     0.0
# 171          0.600              350            0         0     0.0
# 37           0.560              325            0         0     0.0
# 203          0.700              296            0        10     0.0
# 109          0.550              350            0         0     0.0
#
#      Aggregate (CA/ FA)  Curing Days  Curing condition
# 157                2.00          365                 0
# 69                 2.00           28                 0
# 105                2.00           90                 0
# 16                 1.67           28                 0
# 173                1.80           28                 0
# ..                  ...          ...               ...
# 102                2.00           90                 0
# 171                1.60           28                 0
# 37                 1.50            7                 1
# 203                1.20            3                 0
# 109                2.00           90                 0
#
# [181 rows x 8 columns]

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state=0)
regressor.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
y_predict = regressor.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error , r2_score

mse = mean_squared_error(y_test, y_predict)
rmse = np.sqrt(mse)
r2_score(y_test ,y_predict)

print('Mean squared Error:', mse)
print('Root Mean squared Error:', rmse)
print('R-squared:', rmse)
# Out:
# Mean squared Error: 0.6750803278688527
# Root Mean squared Error: 0.8216327207876113
# R-squared: 0.8216327207876113

# %%
temp = [(y_test.values[i], y_predict[i]) for i in range(len(y_predict))]
temp = sorted(temp, key=lambda x: x[0])
temp1 = [u for (u,v) in temp]
temp2 = [v for (u,v) in temp]
x_axis = np.array(range(len(temp1)))
plt.plot(x_axis, temp1)
plt.plot(x_axis, temp2)
plt.show()
